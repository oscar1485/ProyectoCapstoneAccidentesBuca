# %% [markdown]
# <a href="https://www.bigdatauniversity.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ESedX20816812-2022-01-01"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Proyecto Final Coursera Capstone Accidentes- Agrupación y Segmentación de barrios en la Ciudad de bucaramanga, colombia</font></h1>

# %% [markdown]
# ## SEMANA 1

# %% [markdown]
# **Introducción**

# %% [markdown]
# En la actualidad, los accidentes de tránsito representan una preocupación constante en las ciudades de todo el mundo. Bucaramanga, una ciudad en Colombia, no es una excepción. La seguridad vial es un tema crucial que afecta no solo a los conductores y peatones, sino también a la infraestructura urbana, los servicios de emergencia y la calidad de vida en general. Con el aumento del tráfico, la diversidad de vehículos en las carreteras y la interacción entre diferentes modos de transporte, la identificación de patrones y factores relacionados con los accidentes de tránsito se ha convertido en una prioridad para las autoridades y la comunidad en Bucaramanga.

# %% [markdown]
# **El Problema**

# %% [markdown]
# El objetivo principal de este proyecto es analizar y comprender los patrones de accidentes de tránsito en la ciudad de Bucaramanga. Para lograrlo, se utilizará un conjunto de datos que registra la ubicación de accidentes de tránsito en la ciudad. El análisis de estos datos permitirá identificar áreas problemáticas, factores de riesgo y tendencias que contribuyen a la ocurrencia de accidentes. Además, se buscará desarrollar recomendaciones y estrategias para mejorar la seguridad vial y reducir la frecuencia y gravedad de los accidentes.

# %% [markdown]
# **El Conjunto de Datos**

# %% [markdown]
# El conjunto de datos utilizado en este proyecto contiene información detallada sobre los accidentes de tránsito en Bucaramanga. Cada registro incluye datos como la ubicación geográfica (latitud y longitud), la fecha y hora del accidente, las condiciones climáticas, el tipo de vehículos involucrados, la causa probable del accidente y otros detalles relevantes. Estos datos proporcionarán una visión holística de los accidentes en la ciudad y permitirán un análisis profundo de los factores subyacentes.
#
# Los datos que se utilizarán para resolver el problema de los accidentes de tránsito en Bucaramanga provienen de un conjunto de datos que registra información detallada sobre los accidentes. A continuación, se describen las variables presentes en el conjunto de datos:
#
# 1. **ORDEN**: Un identificador único para cada registro de accidente.
# 2. **FECHA**: La fecha en que ocurrió el accidente.
# 3. **AÑO**: El año en que ocurrió el accidente.
# 4. **MES**: El mes en que ocurrió el accidente.
# 5. **DÍA**: El día de la semana en que ocurrió el accidente.
# 6. **GRAVEDAD**: Indica la gravedad del accidente (Con Heridos, Solo Daños, etc.).
# 7. **PEATON**: Número de peatones involucrados en el accidente.
# 8. **AUTOMOVIL, CAMPAERO, CAMIONETA, MICRO, BUSETA, BUS, CAMION, VOLQUETA, MOTO, BICICLETA, OTRO**: Números de diferentes tipos de vehículos involucrados en el accidente.
# 9. **VIA 1**: La vía principal donde ocurrió el accidente.
# 10. **BARRIO**: El barrio o ubicación donde ocurrió el accidente.
# 11. **HORA**: La hora del día en que ocurrió el accidente.
# 12. **ENTIDAD**: La entidad que atendió el accidente.
# 13. **nombrecomuna**: El nombre de la comuna en la que ocurrió el accidente.
# 14. **Propietario de Vehículo**: Propietario del vehículo involucrado.
# 15. **DIURNIO/NOCTURNO**: Indica si el accidente ocurrió durante el día o la noche.
# 16. **HORA RESTRICCION MOTO**: Información sobre la restricción de motocicletas.
#
# Este conjunto de datos proporciona información valiosa sobre las características de los accidentes, incluyendo la ubicación geográfica, la gravedad, los tipos de vehículos involucrados y la hora del día en que ocurren. Además de estos datos, se utilizarán los datos de ubicación de Foursquare para enriquecer el análisis. Los datos de Foursquare pueden incluir información sobre la densidad de tráfico, la presencia de infraestructura vial (señales, semáforos, pasos de peatones, etc.) y la ubicación de establecimientos como hospitales y estaciones de policía, que podrían ser relevantes para el análisis de accidentes de tránsito.
#
# La combinación de estos datos permitirá realizar un análisis más completo y profundo de los accidentes de tránsito en Bucaramanga, identificando patrones, tendencias y factores de riesgo que contribuyen a la ocurrencia de accidentes en la ciudad.

# %% [markdown]
# ## SEMANA 2

# %% [markdown]
# ### Cargar Datos de accidentes

# %%
import pandas as pd

# Cargar el archivo "accidentes.csv" en un DataFrame utilizando el delimitador ;
archivo_csv = "accidentes.csv"
df = pd.read_csv(archivo_csv, delimiter=";")

# Mostrar las primeras filas del DataFrame para verificar la carga exitosa
df
# Out:
#        ORDEN       FECHA   AÑO          MES          DÍA     GRAVEDAD  PEATON  \
# 0          1  01/01/2012  2012    01. Enero  07. Domingo  Con Heridos       0
# 1       2310  21/07/2012  2012    07. Julio   06. Sabado  Con Heridos       0
# 2          3  01/01/2012  2012    01. Enero  07. Domingo   Solo Daños       0
# 3          4  01/01/2012  2012    01. Enero  07. Domingo   Solo Daños       0
# 4          5  01/01/2012  2012    01. Enero  07. Domingo  Con Heridos       1
# ...      ...         ...   ...          ...          ...          ...     ...
# 38192  38193  06/02/2023  2023  02. Febrero    01. Lunes  Con muertos       0
# 38193  24373  03/04/2018  2018    04. Abril   02. Martes   Solo Daños       0
# 38194  38195  17/02/2023  2023  02. Febrero  05. Viernes  Con muertos       0
# 38195  38196  19/02/2023  2023  02. Febrero  07. Domingo  Con muertos       0
# 38196  24396  05/04/2018  2018    04. Abril   04. Jueves   Solo Daños       0
#
# ...

# %% [markdown]
# ### Crear un nuevo dataframe con los registros que tiene codigo postal

# %%
# Crear un nuevo DataFrame con las filas que tienen un CODIGO_POSTAL asignado
df_procesado = df[df['CODIGO_POSTAL'] != '#N/D'].copy()

# Mostrar las primeras filas del DataFrame procesado
df_procesado
# Out:
#        ORDEN       FECHA   AÑO          MES          DÍA     GRAVEDAD  PEATON  \
# 0          1  01/01/2012  2012    01. Enero  07. Domingo  Con Heridos       0
# 2          3  01/01/2012  2012    01. Enero  07. Domingo   Solo Daños       0
# 3          4  01/01/2012  2012    01. Enero  07. Domingo   Solo Daños       0
# 4          5  01/01/2012  2012    01. Enero  07. Domingo  Con Heridos       1
# 5          6  01/01/2012  2012    01. Enero  07. Domingo   Solo Daños       0
# ...      ...         ...   ...          ...          ...          ...     ...
# 38188  38189  28/02/2023  2023  02. Febrero   02. Martes  Con heridos       0
# 38190  38191  28/02/2023  2023  02. Febrero   02. Martes   Solo daños       0
# 38192  38193  06/02/2023  2023  02. Febrero    01. Lunes  Con muertos       0
# 38194  38195  17/02/2023  2023  02. Febrero  05. Viernes  Con muertos       0
# 38195  38196  19/02/2023  2023  02. Febrero  07. Domingo  Con muertos       0
#
# ...

# %%
# Usar el método .shape en el DataFrame df_procesado
shape = df_procesado.shape
# La variable 'shape' contendrá una tupla con la cantidad de filas y columnas en el DataFrame

# Imprimir la información de la forma del DataFrame
print("Número de filas:", shape[0])
print("Número de columnas:", shape[1])
# Out:
# Número de filas: 30091
# Número de columnas: 27

# %% [markdown]
# ### Crear un nuevo dataframe para trabajar solo con el año 2023

# %% [markdown]
# En este análisis, se ha decidido delimitar el estudio únicamente al año 2023. Esta decisión se fundamenta en la necesidad de optimizar el proceso de obtención de coordenadas geográficas a partir de los códigos postales de los registros. Al centrar la atención en un año específico, en este caso el 2023, se busca reducir la carga de procesamiento al trabajar con una cantidad más manejable de datos.
#
# Además, la limitación al año 2023 permite enfocarse en analizar tendencias y patrones específicos de ese período temporal en particular. Esto facilita la interpretación de los resultados y proporciona una visión más detallada de la situación de los accidentes de tránsito en la ciudad de Bucaramanga durante ese año.

# %%
# Filtrar el DataFrame original para obtener solo los registros con año 2023
df_2023 = df_procesado[df_procesado['AÑO'] == 2023].copy()

# Mostrar las primeras filas del nuevo DataFrame
df_2023.head()
# Out:
#       ORDEN       FECHA   AÑO          MES            DÍA     GRAVEDAD  \
# 5667  37988  01/01/2023  2023    01. Enero    07. Domingo   Solo Daños
# 5672  38028  18/01/2023  2023    01. Enero  03. Miercoles  Con Heridos
# 5674  38030  19/01/2023  2023    01. Enero     04. Jueves  Con Heridos
# 5675  38116  08/02/2023  2023  02. Febrero  03. Miercoles  Con heridos
# 5676  38129  11/02/2023  2023  02. Febrero     06. Sabado  Con heridos
#
#       PEATON  AUTOMOVIL  CAMPAERO  CAMIONETA  ...  OTRO        VIA 1  \
# 5667       0          0         0          0  ...     0      CARRERA
# 5672       1          0         0          0  ...     0  AVDA Q SECA
# 5674       0          0         0          0  ...     0        CALLE
# 5675       0          0         0          0  ...     0        CALLE
# 5676       0          1         0          0  ...     0      CARRERA
#
#                      BARRIO            HORA      ENTIDAD  nombrecomuna  \
# ...

# %%
df_2023.reset_index(drop=True, inplace=True)

# %%
df_2023
# Out:
#      ORDEN       FECHA   AÑO          MES            DÍA     GRAVEDAD  PEATON  \
# 0    37988  01/01/2023  2023    01. Enero    07. Domingo   Solo Daños       0
# 1    38028  18/01/2023  2023    01. Enero  03. Miercoles  Con Heridos       1
# 2    38030  19/01/2023  2023    01. Enero     04. Jueves  Con Heridos       0
# 3    38116  08/02/2023  2023  02. Febrero  03. Miercoles  Con heridos       0
# 4    38129  11/02/2023  2023  02. Febrero     06. Sabado  Con heridos       0
# ..     ...         ...   ...          ...            ...          ...     ...
# 149  38189  28/02/2023  2023  02. Febrero     02. Martes  Con heridos       0
# 150  38191  28/02/2023  2023  02. Febrero     02. Martes   Solo daños       0
# 151  38193  06/02/2023  2023  02. Febrero      01. Lunes  Con muertos       0
# 152  38195  17/02/2023  2023  02. Febrero    05. Viernes  Con muertos       0
# 153  38196  19/02/2023  2023  02. Febrero    07. Domingo  Con muertos       0
#
# ...

# %%
# Usar el método .shape en el DataFrame df_procesado
shape = df_2023.shape
# La variable 'shape' contendrá una tupla con la cantidad de filas y columnas en el DataFrame

# Imprimir la información de la forma del DataFrame
print("Número de filas:", shape[0])
print("Número de columnas:", shape[1])
# Out:
# Número de filas: 154
# Número de columnas: 27

# %% [markdown]
# ### Obtener las coordenadas de latitud y longitud de cada vecindario.

# %% [markdown]
# La metodología utilizada involucrará técnicas de análisis de datos geoespaciales y minería de datos. Se realizará un análisis exploratorio de los datos para identificar patrones espaciales y temporales. Luego, se aplicarán técnicas de visualización y modelado para comprender mejor las áreas de alta concentración de accidentes, los horarios críticos y los factores desencadenantes. Además, se evaluarán posibles correlaciones entre variables como el clima, el tipo de vehículo y la gravedad del accidente.

# %%
import geocoder

# Definición de la función para obtener coordenadas
def get_coordinates(postal_code):
    g = geocoder.arcgis('{}, Bucaramanga, Santander, Colombia'.format(postal_code))
    lat_lng = g.latlng
    return lat_lng

# Realizar una copia del DataFrame result_df_filtered
result_df_copy = df_2023.copy()

# Obtener las coordenadas para cada vecindario usando el código postal
result_df_copy[['Latitude', 'Longitude']] = result_df_copy.apply(lambda row: pd.Series(get_coordinates(row['CODIGO_POSTAL'])), axis=1)

# El DataFrame result_df_copy ahora contiene las coordenadas geográficas (latitud y longitud) para cada vecindario
result_df_copy
# Out:
#      ORDEN       FECHA   AÑO          MES            DÍA     GRAVEDAD  PEATON  \
# 0    37988  01/01/2023  2023    01. Enero    07. Domingo   Solo Daños       0
# 1    38028  18/01/2023  2023    01. Enero  03. Miercoles  Con Heridos       1
# 2    38030  19/01/2023  2023    01. Enero     04. Jueves  Con Heridos       0
# 3    38116  08/02/2023  2023  02. Febrero  03. Miercoles  Con heridos       0
# 4    38129  11/02/2023  2023  02. Febrero     06. Sabado  Con heridos       0
# ..     ...         ...   ...          ...            ...          ...     ...
# 149  38189  28/02/2023  2023  02. Febrero     02. Martes  Con heridos       0
# 150  38191  28/02/2023  2023  02. Febrero     02. Martes   Solo daños       0
# 151  38193  06/02/2023  2023  02. Febrero      01. Lunes  Con muertos       0
# 152  38195  17/02/2023  2023  02. Febrero    05. Viernes  Con muertos       0
# 153  38196  19/02/2023  2023  02. Febrero    07. Domingo  Con muertos       0
#
# ...

# %% [markdown]
# ### Agrupar los Barrios por comunas de Bucaramanga donde mas hay accidentes de transito

# %%
# Agrupar los  por el nombre del barrio (BARRIO) y contar la cantidad de accidentes en cada comuna
barrios_grouped = result_df_copy.groupby('nombrecomuna')['BARRIO'].count()

# Mostrar los resultados
print(barrios_grouped)
# Out:
# nombrecomuna
# 01. NORTE                  5
# 03. SAN FRANCISCO         38
# 04. OCCIDENTAL             7
# 05. GARCIA ROVIRA          6
# 06. LA CONCORDIA           5
# 09. LA PEDREGOSA           2
# 10. PROVENZA              12
# 12. CABECERA DEL LLANO    33
# 13. ORIENTAL              21
# 14. MORRORICO              2
# 15. CENTRO                15
# 16. LAGOS DEL CACIQUE      6
# 17. MUTIS                  2
# Name: BARRIO, dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import os

# Seleccionar características relevantes para el análisis de agrupamiento (en este caso, Latitud y Longitud)
features = result_df_copy[['Latitude', 'Longitude']]

# Configurar OMP_NUM_THREADS para evitar la advertencia sobre memoria en Windows con MKL
os.environ['OMP_NUM_THREADS'] = '1'

# Aplicar k-means para agrupar los vecindarios
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
result_df_copy['Cluster'] = kmeans.fit_predict(features)

# Visualizar los clústeres en un gráfico de dispersión
plt.scatter(result_df_copy['Latitude'], result_df_copy['Longitude'], c=result_df_copy['Cluster'], cmap='rainbow')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Clustering of Toronto Neighborhoods')
plt.show()
# Out:
# C:\Users\DIAZOVIEDO\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# **Beneficios y Resultados Esperados**

# %% [markdown]
# <h2><a href="https://oscar1485.github.io/ProyectoCapstoneAccidentesBuca/bucaramanga_neighborhoods_clusters.html" target="_blank">Abrir enlace, para ver el mapa interactivo</a></h2>

# %%
from IPython.display import display, HTML
import folium
from folium.plugins import MarkerCluster

# Crear un mapa centrado en Bucaramanga
bucaramanga_map = folium.Map(location=[7.11392, -73.1198], zoom_start=12)

# Agregar marcadores para los vecindarios con colores según el clúster
marker_cluster = MarkerCluster().add_to(bucaramanga_map)

for idx, row in result_df_copy.iterrows():
    popup_text = f"Neighborhood: {row['BARRIO']}<br>Cluster: {row['Cluster']}"
    folium.Marker([row['Latitude'], row['Longitude']], popup=popup_text).add_to(marker_cluster)

# Generar el HTML del mapa
bucaramanga_map_html = bucaramanga_map._repr_html_()

# Guardar el mapa en un archivo HTML
bucaramanga_map.save('bucaramanga_neighborhoods_clusters.html')

# Mostrar el mapa en una celda directamente
display(HTML(bucaramanga_map_html))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# El análisis de este proyecto proporcionará una visión más clara de los patrones y tendencias de accidentes de tránsito en Bucaramanga. Los resultados podrán ser utilizados por las autoridades locales y las organizaciones de seguridad vial para implementar estrategias específicas de prevención y mejora de la seguridad en las áreas más afectadas. La comunidad también se beneficiará al tener una comprensión más completa de los riesgos y desafíos relacionados con la seguridad vial en la ciudad.

# %% [markdown]
# En el análisis realizado sobre los datos de accidentes de tránsito en la ciudad de Bucaramanga, se han examinado detalladamente las incidencias en distintas comunas de la ciudad. Cada comuna se presenta junto con el número de accidentes registrados en ella durante el período considerado.
#
# Este recuento de accidentes por comuna proporciona información valiosa para comprender la distribución geográfica de los incidentes y las áreas de la ciudad que podrían requerir una mayor atención en términos de seguridad vial. Por ejemplo:
#
# - La comuna "NORTE" ha registrado 5 accidentes, lo que sugiere un bajo nivel de incidentes en esa área.
# - Por otro lado, la comuna "SAN FRANCISCO" destaca con 38 accidentes, lo que puede indicar una mayor necesidad de medidas de seguridad en esa zona.
#
# El análisis de esta naturaleza es esencial para que las autoridades pertinentes y los planificadores urbanos tomen decisiones informadas sobre cómo asignar recursos para mejorar la seguridad vial en diferentes áreas de la ciudad. Este enfoque basado en datos puede contribuir significativamente a la reducción de accidentes y la promoción de la seguridad en las vías públicas.

# %% [markdown]
# Comuna "SAN FRANCISCO": Con un total de 38 accidentes, esta comuna lidera la lista en términos de incidentes de tránsito. La alta concentración de accidentes podría indicar áreas específicas dentro de esta comuna que requieren intervenciones de seguridad vial.
#
# Comuna "CABECERA DEL LLANO": Esta comuna reporta un total de 33 accidentes, lo que la coloca en una posición destacada en la lista. La cantidad significativa de accidentes puede señalar la necesidad de evaluar las condiciones viales y aplicar medidas preventivas.
#
# Comuna "ORIENTAL": Con 21 accidentes, la comuna Oriental también se encuentra entre las que registran un número considerable de incidentes. La identificación de patrones de accidentes en esta área podría contribuir a la formulación de estrategias de prevención.
#
# Comuna "PROVENZA": Esta comuna presenta 12 accidentes en el período analizado. Aunque la cifra es menor que las anteriores, sigue siendo relevante para el análisis de seguridad vial.
#
# Comuna "CENTRO": Con un total de 15 accidentes, la comuna Centro también figura en la lista de comunas con una cantidad significativa de incidentes. Dada su ubicación central, es crucial abordar los factores que contribuyen a estos accidentes.
